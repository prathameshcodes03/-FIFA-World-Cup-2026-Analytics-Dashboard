# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../analytics/matches_cleaned.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ROUND                  104 non-null    object
#  1   DAYOFWEEK              104 non-null    object
#  2   DATE                   104 non-null    object
#  3   START_TIME             104 non-null    object
#  4   HOME_TEAM              104 non-null    object
#  5   AWAY_TEAM              104 non-null    object
#  6   SCORE                  104 non-null    object
#  7   HOME_SCORE             104 non-null    int64
#  8   AWAY_SCORE             104 non-null    int64
#  9   ATTENDANCE             104 non-null    int64
#  10  VENUE                  104 non-null    object
#  11  REFEREE                104 non-null    object
#  12  HOME_FORMATION         104 non-null    object
#  13  AWAY_FORMATION         104 non-null    object
# ...

# %%
data.shape
# Out:
# (104, 48)

# %%
data.head(5)
# Out:
#          ROUND DAYOFWEEK        DATE START_TIME       HOME_TEAM     AWAY_TEAM  \
# 0  Group stage       Thu  2026-06-11      13:00          Mexico  South Africa
# 1  Group stage       Thu  2026-06-11      20:00  Korea Republic       Czechia
# 2  Group stage       Fri  2026-06-12      15:00          Canada   Bosnia–Herz
# 3  Group stage       Fri  2026-06-12      18:00   United States      Paraguay
# 4  Group stage       Sat  2026-06-13      12:00           Qatar   Switzerland
#
#   SCORE  HOME_SCORE  AWAY_SCORE  ATTENDANCE  ... HOME_OFFSIDES AWAY_OFFSIDES  \
# 0   2–0           2           0       80824  ...             1             1
# 1   2–1           2           1       44985  ...             2             2
# 2   1–1           1           1       43002  ...             1             0
# 3   4–1           4           1       70492  ...             2             1
# 4   1–1           1           1       67966  ...             0             1
#
# ...

# %%
data.columns
# Out:
# Index(['ROUND', 'DAYOFWEEK', 'DATE', 'START_TIME', 'HOME_TEAM', 'AWAY_TEAM',
#        'SCORE', 'HOME_SCORE', 'AWAY_SCORE', 'ATTENDANCE', 'VENUE', 'REFEREE',
#        'HOME_FORMATION', 'AWAY_FORMATION', 'HOME_MANAGER', 'AWAY_MANAGER',
#        'HOME_CAPTAIN', 'AWAY_CAPTAIN', 'HOME_POSSESSION', 'AWAY_POSSESSION',
#        'HOME_SOT', 'AWAY_SOT', 'HOME_TOTAL_SHOTS', 'AWAY_TOTAL_SHOTS',
#        'HOME_SAVES', 'AWAY_SAVES', 'HOME_CARDS_YELLOW', 'AWAY_CARDS_YELLOW',
#        'HOME_CARDS_RED', 'AWAY_CARDS_RED', 'HOME_FOULS', 'AWAY_FOULS',
#        'HOME_CORNERS', 'AWAY_CORNERS', 'HOME_CROSSES', 'AWAY_CROSSES',
#        'HOME_INTERCEPTIONS', 'AWAY_INTERCEPTIONS', 'HOME_OFFSIDES',
#        'AWAY_OFFSIDES', 'TOTAL_GOALS', 'GOAL_DIFFERENCE', 'MATCH_RESULT',
#        'TOTAL_YELLOW_CARDS', 'TOTAL_RED_CARDS', 'TOTAL_SHOTS_ON_TARGET',
#        'TOTAL_CORNERS', 'TOTAL_SAVES'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# ROUND                    0
# DAYOFWEEK                0
# DATE                     0
# START_TIME               0
# HOME_TEAM                0
# AWAY_TEAM                0
# SCORE                    0
# HOME_SCORE               0
# AWAY_SCORE               0
# ATTENDANCE               0
# VENUE                    0
# REFEREE                  0
# HOME_FORMATION           0
# AWAY_FORMATION           0
# HOME_MANAGER             0
# AWAY_MANAGER             0
# HOME_CAPTAIN             0
# AWAY_CAPTAIN             0
# HOME_POSSESSION          0
# AWAY_POSSESSION          0
# HOME_SOT                 0
# AWAY_SOT                 0
# HOME_TOTAL_SHOTS         0
# AWAY_TOTAL_SHOTS         0
# HOME_SAVES               0
# AWAY_SAVES               0
# HOME_CARDS_YELLOW        0
# AWAY_CARDS_YELLOW        0
# HOME_CARDS_RED           0
# AWAY_CARDS_RED           0
# HOME_FOULS               0
# AWAY_FOULS               0
# HOME_CORNERS             0
# AWAY_CORNERS             0
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dtypes
# Out:
# ROUND                    object
# DAYOFWEEK                object
# DATE                     object
# START_TIME               object
# HOME_TEAM                object
# AWAY_TEAM                object
# SCORE                    object
# HOME_SCORE                int64
# AWAY_SCORE                int64
# ATTENDANCE                int64
# VENUE                    object
# REFEREE                  object
# HOME_FORMATION           object
# AWAY_FORMATION           object
# HOME_MANAGER             object
# AWAY_MANAGER             object
# HOME_CAPTAIN             object
# AWAY_CAPTAIN             object
# HOME_POSSESSION           int64
# AWAY_POSSESSION           int64
# HOME_SOT                  int64
# AWAY_SOT                  int64
# HOME_TOTAL_SHOTS          int64
# AWAY_TOTAL_SHOTS          int64
# HOME_SAVES                int64
# AWAY_SAVES                int64
# HOME_CARDS_YELLOW         int64
# AWAY_CARDS_YELLOW         int64
# HOME_CARDS_RED            int64
# ...

# %%
##Descriptive Analysis


descriptive_analysis = data.describe()
descriptive_analysis
# Out:
#        HOME_SCORE  AWAY_SCORE    ATTENDANCE  HOME_POSSESSION  AWAY_POSSESSION  \
# count  104.000000  104.000000    104.000000       104.000000       104.000000
# mean     1.692308    1.211538  65490.057692        52.423077        47.701923
# std      1.526955    1.251586  10052.949890        13.101317        13.093302
# min      0.000000    0.000000  42942.000000        24.000000        21.000000
# 25%      0.750000    0.000000  63998.000000        43.000000        38.000000
# 50%      1.000000    1.000000  68276.000000        52.500000        47.500000
# 75%      3.000000    2.000000  70046.500000        62.000000        57.000000
# max      7.000000    6.000000  80824.000000        79.000000        76.000000
#
#          HOME_SOT    AWAY_SOT  HOME_TOTAL_SHOTS  AWAY_TOTAL_SHOTS  HOME_SAVES  \
# count  104.000000  104.000000        104.000000        104.000000  104.000000
# mean     4.846154    3.673077         14.019231         10.769231    2.403846
# ...

# %%
### Descriptive Statistics of Important Match Statistics

""" The following table summarizes key numerical variables such as goals, attendance, possession, and total shots. These statistics provide a concise overview of match performance throughout the tournament. """





descriptive_analysis[['HOME_SCORE', 
 'AWAY_SCORE',
'TOTAL_GOALS' ,
 'ATTENDANCE' ,
 'HOME_POSSESSION' ,
'AWAY_POSSESSION' ,
'HOME_TOTAL_SHOTS' , 
 'AWAY_TOTAL_SHOTS']]
# Out:
#        HOME_SCORE  AWAY_SCORE  TOTAL_GOALS    ATTENDANCE  HOME_POSSESSION  \
# count  104.000000  104.000000   104.000000    104.000000       104.000000
# mean     1.692308    1.211538     2.903846  65490.057692        52.423077
# std      1.526955    1.251586     1.923383  10052.949890        13.101317
# min      0.000000    0.000000     0.000000  42942.000000        24.000000
# 25%      0.750000    0.000000     1.750000  63998.000000        43.000000
# 50%      1.000000    1.000000     3.000000  68276.000000        52.500000
# 75%      3.000000    2.000000     4.000000  70046.500000        62.000000
# max      7.000000    6.000000    10.000000  80824.000000        79.000000
#
#        AWAY_POSSESSION  HOME_TOTAL_SHOTS  AWAY_TOTAL_SHOTS
# count       104.000000        104.000000        104.000000
# mean         47.701923         14.019231         10.769231
# std          13.093302          6.422020          5.846301
# min          21.000000          2.000000          2.000000
# ...

# %%
data.describe(include="object")
# Out:
#               ROUND DAYOFWEEK        DATE START_TIME HOME_TEAM AWAY_TEAM  \
# count           104       104         104        104       104       104
# unique            7         7          34         14        48        48
# top     Group stage       Sat  2026-06-26      12:00    France   Morocco
# freq             72        19           6         23         6         5
#
#        SCORE                    VENUE         REFEREE HOME_FORMATION  \
# count    104                      104             104            104
# unique    31                       17              43             10
# top      1–1  AT&T Stadium, Arlington  Clément Turpin        4-2-3-1
# freq       9                        9               4             34
#
#        AWAY_FORMATION      HOME_MANAGER    AWAY_MANAGER   HOME_CAPTAIN  \
# count             104               104             104            104
# unique             10                48              49             52
# ...

# %%
## Measures of Central Tendency

mean_values = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].mean()

mean_values
# Out:
# HOME_SCORE              1.692308
# AWAY_SCORE              1.211538
# TOTAL_GOALS             2.903846
# ATTENDANCE          65490.057692
# HOME_POSSESSION        52.423077
# AWAY_POSSESSION        47.701923
# HOME_TOTAL_SHOTS       14.019231
# AWAY_TOTAL_SHOTS       10.769231
# dtype: float64

# %%
median_values = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].median()

median_values
# Out:
# HOME_SCORE              1.0
# AWAY_SCORE              1.0
# TOTAL_GOALS             3.0
# ATTENDANCE          68276.0
# HOME_POSSESSION        52.5
# AWAY_POSSESSION        47.5
# HOME_TOTAL_SHOTS       13.0
# AWAY_TOTAL_SHOTS       10.0
# dtype: float64

# %%
mode_values = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].mode()

mode_values
# Out:
#    HOME_SCORE  AWAY_SCORE  TOTAL_GOALS  ATTENDANCE  HOME_POSSESSION  \
# 0         1.0         1.0          3.0       52497             48.0
# 1         NaN         NaN          NaN       80663              NaN
#
#    AWAY_POSSESSION  HOME_TOTAL_SHOTS  AWAY_TOTAL_SHOTS
# 0             52.0                 8               7.0
# 1              NaN                10               NaN

# %%
central_tendency = pd.DataFrame({
    "Mean": mean_values,
    "Median": median_values,
    "Mode": mode_values.iloc[0]
})

central_tendency
# Out:
#                           Mean   Median     Mode
# HOME_SCORE            1.692308      1.0      1.0
# AWAY_SCORE            1.211538      1.0      1.0
# TOTAL_GOALS           2.903846      3.0      3.0
# ATTENDANCE        65490.057692  68276.0  52497.0
# HOME_POSSESSION      52.423077     52.5     48.0
# AWAY_POSSESSION      47.701923     47.5     52.0
# HOME_TOTAL_SHOTS     14.019231     13.0      8.0
# AWAY_TOTAL_SHOTS     10.769231     10.0      7.0

# %%
## Measures of Despersion

Variance = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].var()


Variance
# Out:
# HOME_SCORE          2.331591e+00
# AWAY_SCORE          1.566468e+00
# TOTAL_GOALS         3.699403e+00
# ATTENDANCE          1.010618e+08
# HOME_POSSESSION     1.716445e+02
# AWAY_POSSESSION     1.714346e+02
# HOME_TOTAL_SHOTS    4.124235e+01
# AWAY_TOTAL_SHOTS    3.417924e+01
# dtype: float64

# %%
STD = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].std()


STD
# Out:
# HOME_SCORE              1.526955
# AWAY_SCORE              1.251586
# TOTAL_GOALS             1.923383
# ATTENDANCE          10052.949890
# HOME_POSSESSION        13.101317
# AWAY_POSSESSION        13.093302
# HOME_TOTAL_SHOTS        6.422020
# AWAY_TOTAL_SHOTS        5.846301
# dtype: float64

# %%
RANGE = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].max() - data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].min()

RANGE
# Out:
# HOME_SCORE              7
# AWAY_SCORE              6
# TOTAL_GOALS            10
# ATTENDANCE          37882
# HOME_POSSESSION        55
# AWAY_POSSESSION        55
# HOME_TOTAL_SHOTS       30
# AWAY_TOTAL_SHOTS       33
# dtype: int64

# %%
## Quartiles & Percentiles

q1 = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].quantile(0.25)

q1
# Out:
# HOME_SCORE              0.75
# AWAY_SCORE              0.00
# TOTAL_GOALS             1.75
# ATTENDANCE          63998.00
# HOME_POSSESSION        43.00
# AWAY_POSSESSION        38.00
# HOME_TOTAL_SHOTS        8.75
# AWAY_TOTAL_SHOTS        7.00
# Name: 0.25, dtype: float64

# %%
q2 = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].quantile(0.50)

q2
# Out:
# HOME_SCORE              1.0
# AWAY_SCORE              1.0
# TOTAL_GOALS             3.0
# ATTENDANCE          68276.0
# HOME_POSSESSION        52.5
# AWAY_POSSESSION        47.5
# HOME_TOTAL_SHOTS       13.0
# AWAY_TOTAL_SHOTS       10.0
# Name: 0.5, dtype: float64

# %%
q3 = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].quantile(0.75)

q3
# Out:
# HOME_SCORE              3.0
# AWAY_SCORE              2.0
# TOTAL_GOALS             4.0
# ATTENDANCE          70046.5
# HOME_POSSESSION        62.0
# AWAY_POSSESSION        57.0
# HOME_TOTAL_SHOTS       19.0
# AWAY_TOTAL_SHOTS       14.0
# Name: 0.75, dtype: float64

# %%
iqr = q3 - q1

iqr
# Out:
# HOME_SCORE             2.25
# AWAY_SCORE             2.00
# TOTAL_GOALS            2.25
# ATTENDANCE          6048.50
# HOME_POSSESSION       19.00
# AWAY_POSSESSION       19.00
# HOME_TOTAL_SHOTS      10.25
# AWAY_TOTAL_SHOTS       7.00
# dtype: float64

# %%
percentiles = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].quantile([0.10, 0.25, 0.50, 0.75, 0.90])

percentiles
# Out:
#       HOME_SCORE  AWAY_SCORE  TOTAL_GOALS  ATTENDANCE  HOME_POSSESSION  \
# 0.10        0.00         0.0         0.30     51063.8             33.3
# 0.25        0.75         0.0         1.75     63998.0             43.0
# 0.50        1.00         1.0         3.00     68276.0             52.5
# 0.75        3.00         2.0         4.00     70046.5             62.0
# 0.90        4.00         3.0         5.00     80663.0             68.7
#
#       AWAY_POSSESSION  HOME_TOTAL_SHOTS  AWAY_TOTAL_SHOTS
# 0.10             31.3              7.00               5.0
# 0.25             38.0              8.75               7.0
# 0.50             47.5             13.00              10.0
# 0.75             57.0             19.00              14.0
# 0.90             66.7             22.00              17.7

# %%
quartile_summary = pd.DataFrame({
    "Q1 (25%)": q1,
    "Q2 (Median)": q2,
    "Q3 (75%)": q3,
    "IQR": iqr
})

quartile_summary
# Out:
#                   Q1 (25%)  Q2 (Median)  Q3 (75%)      IQR
# HOME_SCORE            0.75          1.0       3.0     2.25
# AWAY_SCORE            0.00          1.0       2.0     2.00
# TOTAL_GOALS           1.75          3.0       4.0     2.25
# ATTENDANCE        63998.00      68276.0   70046.5  6048.50
# HOME_POSSESSION      43.00         52.5      62.0    19.00
# AWAY_POSSESSION      38.00         47.5      57.0    19.00
# HOME_TOTAL_SHOTS      8.75         13.0      19.0    10.25
# AWAY_TOTAL_SHOTS      7.00         10.0      14.0     7.00

# %%
### Distribution analysis 

skewness = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].skew()

skewness
# Out:
# HOME_SCORE          0.969576
# AWAY_SCORE          1.255321
# TOTAL_GOALS         0.623281
# ATTENDANCE         -0.778382
# HOME_POSSESSION    -0.068218
# AWAY_POSSESSION     0.072316
# HOME_TOTAL_SHOTS    0.628457
# AWAY_TOTAL_SHOTS    1.395952
# dtype: float64

# %%
kurtosis = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].kurt()

kurtosis
# Out:
# HOME_SCORE          0.798578
# AWAY_SCORE          1.725644
# TOTAL_GOALS         0.758555
# ATTENDANCE          0.218581
# HOME_POSSESSION    -0.652169
# AWAY_POSSESSION    -0.645640
# HOME_TOTAL_SHOTS   -0.066299
# AWAY_TOTAL_SHOTS    3.065694
# dtype: float64

# %%
distribution_summary = pd.DataFrame({
    "Skewness": skewness,
    "Kurtosis": kurtosis
})

distribution_summary
# Out:
#                   Skewness  Kurtosis
# HOME_SCORE        0.969576  0.798578
# AWAY_SCORE        1.255321  1.725644
# TOTAL_GOALS       0.623281  0.758555
# ATTENDANCE       -0.778382  0.218581
# HOME_POSSESSION  -0.068218 -0.652169
# AWAY_POSSESSION   0.072316 -0.645640
# HOME_TOTAL_SHOTS  0.628457 -0.066299
# AWAY_TOTAL_SHOTS  1.395952  3.065694

# %%
## Outlier Detection

columns = [
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]

Q1 = data[columns].quantile(0.25)
Q3 = data[columns].quantile(0.75)
IQR = Q3 - Q1

IQR
# Out:
# HOME_SCORE             2.25
# AWAY_SCORE             2.00
# TOTAL_GOALS            2.25
# ATTENDANCE          6048.50
# HOME_POSSESSION       19.00
# AWAY_POSSESSION       19.00
# HOME_TOTAL_SHOTS      10.25
# AWAY_TOTAL_SHOTS       7.00
# dtype: float64

# %%
outliers = ((data[columns] < (Q1 - 1.5 * IQR)) |
            (data[columns] > (Q3 + 1.5 * IQR)))

outliers.sum()
# Out:
# HOME_SCORE           1
# AWAY_SCORE           1
# TOTAL_GOALS          2
# ATTENDANCE          34
# HOME_POSSESSION      0
# AWAY_POSSESSION      0
# HOME_TOTAL_SHOTS     0
# AWAY_TOTAL_SHOTS     4
# dtype: int64

# %%
import matplotlib.pyplot as plt

for column in columns:
    plt.figure(figsize=(6,4))
    plt.boxplot(data[column])
    plt.title(f"Boxplot of {column}")
    plt.ylabel(column)
    plt.grid(True)
    plt.show()

# %%
outlier_summary = pd.DataFrame({
    "Outlier Count": outliers.sum()
})

outlier_summary
# Out:
#                   Outlier Count
# HOME_SCORE                    1
# AWAY_SCORE                    1
# TOTAL_GOALS                   2
# ATTENDANCE                   34
# HOME_POSSESSION               0
# AWAY_POSSESSION               0
# HOME_TOTAL_SHOTS              0
# AWAY_TOTAL_SHOTS              4

# %%
###  Correlation Analysis 

correlation_matrix = data[[
    "HOME_SCORE",
    "AWAY_SCORE",
    "TOTAL_GOALS",
    "ATTENDANCE",
    "HOME_POSSESSION",
    "AWAY_POSSESSION",
    "HOME_SOT",
    "AWAY_SOT",
    "HOME_TOTAL_SHOTS",
    "AWAY_TOTAL_SHOTS"
]].corr()

correlation_matrix
# Out:
#                   HOME_SCORE  AWAY_SCORE  TOTAL_GOALS  ATTENDANCE  \
# HOME_SCORE          1.000000   -0.051974     0.760070    0.031829
# AWAY_SCORE         -0.051974    1.000000     0.609460    0.096088
# TOTAL_GOALS         0.760070    0.609460     1.000000    0.087795
# ATTENDANCE          0.031829    0.096088     0.087795    1.000000
# HOME_POSSESSION     0.333186   -0.276096     0.084852    0.051027
# AWAY_POSSESSION    -0.332904    0.275228    -0.085193   -0.051170
# HOME_SOT            0.599388   -0.211126     0.338464    0.073737
# AWAY_SOT           -0.156177    0.623722     0.281882   -0.031852
# HOME_TOTAL_SHOTS    0.362974   -0.263833     0.116480    0.104461
# AWAY_TOTAL_SHOTS   -0.194005    0.460518     0.145650   -0.065604
#
#                   HOME_POSSESSION  AWAY_POSSESSION  HOME_SOT  AWAY_SOT  \
# HOME_SCORE               0.333186        -0.332904  0.599388 -0.156177
# AWAY_SCORE              -0.276096         0.275228 -0.211126  0.623722
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

plt.imshow(correlation_matrix, cmap="coolwarm", interpolation="nearest" )

plt.colorbar()

plt.xticks(range(len(correlation_matrix.columns)),
           correlation_matrix.columns,
           rotation=90)

plt.yticks(range(len(correlation_matrix.columns)),
           correlation_matrix.columns)

plt.title("Correlation Heatmap of Match Statistics")

plt.tight_layout()
plt.show()

# %%
correlation_matrix.unstack().sort_values(ascending=False).drop_duplicates()
# Out:
# HOME_SCORE        HOME_SCORE          1.000000
# AWAY_TOTAL_SHOTS  AWAY_SOT            0.807802
# HOME_SCORE        TOTAL_GOALS         0.760070
# HOME_TOTAL_SHOTS  HOME_SOT            0.739772
#                   HOME_POSSESSION     0.681639
# AWAY_SOT          AWAY_SCORE          0.623722
# TOTAL_GOALS       AWAY_SCORE          0.609460
# HOME_SCORE        HOME_SOT            0.599388
# HOME_SOT          HOME_POSSESSION     0.546748
# AWAY_TOTAL_SHOTS  AWAY_POSSESSION     0.536357
# AWAY_SCORE        AWAY_TOTAL_SHOTS    0.460518
# AWAY_POSSESSION   AWAY_SOT            0.458399
# HOME_TOTAL_SHOTS  HOME_SCORE          0.362974
# HOME_SOT          TOTAL_GOALS         0.338464
# HOME_SCORE        HOME_POSSESSION     0.333186
# TOTAL_GOALS       AWAY_SOT            0.281882
# AWAY_POSSESSION   AWAY_SCORE          0.275228
# TOTAL_GOALS       AWAY_TOTAL_SHOTS    0.145650
# HOME_TOTAL_SHOTS  TOTAL_GOALS         0.116480
#                   ATTENDANCE          0.104461
# ...

# %%
correlation_matrix.to_csv("../analytics/correlation_matrix.csv", index=True)
